# %%
x = 10

if x > 0:
    print(f"{x} is positive")
elif x == 0:
    print("x is zero")
else:
    print(f"{x} is negative")

# %%
base = 50
height = 30

area = 1/2 * (base * height)

print(area)

# %% [markdown]
# now another chapter will be start

# %%
cost of_ice_bag = 1.25

profit_margin =. 2

number_of_bags = 500
